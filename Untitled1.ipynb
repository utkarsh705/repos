# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,10])
y = np.array([0,250])

plt.plot(x,y)
plt.show()

# %%
#line graph

# %%
x1 =  np.linspace(0,10,100)
y1 = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0, 10])

# %%
x1
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y1
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x1,y1,label='linear')
plt.legend()
plt.show()

# %%
import pandas as pd

# %%
#df2 = pd.read_csv(r"C:\Users\usingh4\Desktop\utk\cs2m.csv")

##df2 = pd.read_csv("C:/Users/usingh4/Desktop/utk/cs2m.csv")

#df2 = pd.read_csv("C:\\Users\\usingh4\\Desktop\\utk\\cs2m.csv")

#df2

# %%
    from matplotlib import pyplot as plt

# %%
import numpy as np
cars = ['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']
data = [23,17,35,29,12,41]
fig = plt.figure(figsize = (5,5))
plt.pie(data,labels = cars)
plt.show()

# %%
import numpy as np
cars = ['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']
data = [23,17,35,29,12,41]
explode = (0.1,0.2,0.0,0.3,0.0,0.0)
colors = ("orange","cyan","brown","grey","indigo","beige")
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
def func(pct, allvalues):
    absolute = int(pct /100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct,absolute)
fix, ax = plt.subplots(figsize = (5,7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct,data),
                                  explode = explode,
                                  labels = cars,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color = "magenta"))
ax.legend(wedges,cars,
          title = "Cars",
          loc = "center left",
          bbox_to_anchor = (1,0,0.5,1))
plt.setp(autotexts,size= 8,weight = "bold")
ax.set_title("Customizing pie chart")
plt.show()

# %%
sd = open('file1')

# %%
sd = open('file1')

# %%
sd1 = open('file_new','w')
sd1.write("how to handle")
sd1.close()
print(sd1)
# Out:
# <_io.TextIOWrapper name='file_new' mode='w' encoding='UTF-8'>

# %%
sd = open('file1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 sd = open('file1')
#
# FileNotFoundError: [Errno 44] No such file or directory: 'file1'

# %%
filename = "emp_file.txt"
f = open('emp_file.txt','a')
for i in range (0,5):
    name = input ("enter a name:")
    f.write(name)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 3>()
#       3 for i in range (0,5):
#       4     name = input ("enter a name:")
# ----> 5     f.write(name)
#       6 f.close()
#
# TypeError: write() argument must be str, not Future
